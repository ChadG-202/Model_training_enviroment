# %%
# Imports
import librosa, librosa.display
import matplotlib.pyplot as plt
import os
import numpy as np
import math
import json
import cv2
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import pickle
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Embedding
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from keras_tuner import HyperModel
from keras_tuner.tuners import RandomSearch
from keras_tuner.tuners import Hyperband
from tensorflow import keras

# %%
# Load data
DATA_PATH = "JSON/TrainData.json"
IMG_SIZE = 48

def load_image_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)
        
    X = np.array(data["image"]).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
    y = np.array(data["labels"])
    return X, y

# %%
X_image, y_image = load_image_data(DATA_PATH)
X_image = X_image.astype("float32")/255.0

# %%
class CNNHyperModel(HyperModel):
    def __init__(self, input_shape, num_classes):
        self.input_shape = input_shape
        self.num_classes = num_classes

    def build(self, hp):
        
        model = Sequential()
        
        # Convolutional 1
        model.add(
            Conv2D(
                filters=hp.Choice(
                    'Cov_filters_1',
                    values=[16, 32, 64],
                    default=32,
                ),
                activation='relu',
                kernel_size=(3,3),
                input_shape=X_image.shape[1:]
            )
        )
        
        # Convolutional 2
        model.add(
            Conv2D(
                filters=hp.Choice(
                    'Cov_filters_2',
                    values=[16, 32, 64],
                    default=32,
                ),
                activation='relu',
                kernel_size=(3,3)
            )
        )

        # Pooling 1
        model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
        
        # Dropout 1
        model.add(
            Dropout(rate=hp.Float(
                'dropout_1',
                min_value=0.0,
                max_value=0.5,
                default=0.2,
                step=0.05
            ))
        )
        
        # Convolutional 3
        model.add(
            Conv2D(
                filters=hp.Choice(
                    'Cov_filters_3',
                    values=[16, 32, 64],
                    default=64,
                ),
                activation='relu',
                kernel_size=(3,3)
            )
        )
        
        # Convolutional 4
        model.add(
            Conv2D(
                filters=hp.Choice(
                    'Cov_filters_4',
                    values=[16, 32, 64],
                    default=64,
                ),
                activation='relu',
                kernel_size=(3,3)
            )
        )

        # Pooling 2
        model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
        
        # Dropout 2
        model.add(
            Dropout(rate=hp.Float(
                'dropout_2',
                min_value=0.0,
                max_value=0.5,
                default=0.1,
                step=0.05
            ))
        )
        
        # Flatten
        model.add(Flatten())
        
        # Hidden layer 1
        model.add(
            Dense(
                units=hp.Int(
                    'units_1',
                    min_value=32,
                    max_value=512,
                    step=32,
                    default=256
                ),
                activation='relu'
            )
        )
        
        # Dropout 4
        model.add(
            Dropout(
                rate=hp.Float(
                    'dropout_4',
                    min_value=0.0,
                    max_value=0.5,
                    default=0.14,
                    step=0.05
                )
            )
        )
        

        model.add(Dense(self.num_classes, activation='softmax'))

        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=hp.Float(
                    'learning_rate',
                    min_value=1e-4,
                    max_value=1e-2,
                    sampling='LOG',
                    default=1e-3
            )),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )
        return model
    
NUM_CLASSES = 3  # happy neutral sad number of classes
INPUT_SHAPE = (48, 48, 1) 
SEED = 1
HYPERBAND_MAX_EPOCHS = 15
MAX_TRIALS = 25
EXECUTION_PER_TRIAL = 2

hypermodel = CNNHyperModel(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES)

tuner = RandomSearch(
    hypermodel,
    objective='val_accuracy',
    seed=SEED,
    max_trials=MAX_TRIALS,
    executions_per_trial=EXECUTION_PER_TRIAL,
    directory='random_search',
    project_name='CNNF1'
)

tuner = Hyperband(
    hypermodel,
    max_epochs=HYPERBAND_MAX_EPOCHS,
    objective='val_accuracy',
    seed=SEED,
    executions_per_trial=EXECUTION_PER_TRIAL,
    directory='hyperband',
    project_name='CNNF1'
)

N_EPOCH_SEARCH = 15
BATCH_SIZE = 2

tuner.search(X_image, y_image, batch_size=BATCH_SIZE, epochs=N_EPOCH_SEARCH, validation_split=0.2)

tuner.results_summary()

# Retrieve the best model.
best_model = tuner.get_best_models(num_models=1)[0]
# Out:
# Trial 30 Complete [00h 02m 24s]
# val_accuracy: 0.9404761791229248
#
# Best val_accuracy So Far: 0.9404761791229248
# Total elapsed time: 00h 19m 22s
# INFO:tensorflow:Oracle triggered exit
# Results summary
# Results in hyperband\CNNF1
# Showing 10 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# Cov_filters_1: 32
# Cov_filters_2: 32
# dropout_1: 0.05
# Cov_filters_3: 16
# Cov_filters_4: 64
# dropout_2: 0.35000000000000003
# units_1: 480
# dropout_4: 0.15000000000000002
# learning_rate: 0.00014023399602325874
# tuner/epochs: 15
# tuner/initial_epoch: 5
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 18e31a008fc892ebbd7b0935b25f6ebe
# Score: 0.9404761791229248
# Trial summary
# Hyperparameters:
# Cov_filters_1: 16
# Cov_filters_2: 64
# dropout_1: 0.2
# Cov_filters_3: 64
# Cov_filters_4: 64
# dropout_2: 0.30000000000000004
# units_1: 352
# dropout_4: 0.25
# learning_rate: 0.00012763132071644807
# tuner/epochs: 15
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.9404761791229248
# Trial summary
# Hyperparameters:
# Cov_filters_1: 32
# Cov_filters_2: 32
# dropout_1: 0.4
# Cov_filters_3: 32
# Cov_filters_4: 16
# dropout_2: 0.5
# units_1: 480
# dropout_4: 0.45
# learning_rate: 0.00019430304760198347
# tuner/epochs: 15
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.9126984179019928
# Trial summary
# Hyperparameters:
# Cov_filters_1: 32
# Cov_filters_2: 32
# dropout_1: 0.4
# Cov_filters_3: 32
# Cov_filters_4: 16
# dropout_2: 0.1
# units_1: 448
# dropout_4: 0.4
# learning_rate: 0.0003021384939866327
# tuner/epochs: 15
# tuner/initial_epoch: 5
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: d23faf60ad1b68ffbf30a93f710c8ef3
# Score: 0.8968254029750824
# Trial summary
# Hyperparameters:
# Cov_filters_1: 64
# Cov_filters_2: 32
# dropout_1: 0.05
# Cov_filters_3: 32
# Cov_filters_4: 16
# dropout_2: 0.15000000000000002
# units_1: 192
# dropout_4: 0.4
# learning_rate: 0.000926543735982781
# tuner/epochs: 15
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.8968254029750824
# Trial summary
# Hyperparameters:
# Cov_filters_1: 16
# Cov_filters_2: 64
# dropout_1: 0.25
# Cov_filters_3: 64
# Cov_filters_4: 64
# dropout_2: 0.2
# units_1: 96
# dropout_4: 0.25
# learning_rate: 0.0001280584792632199
# tuner/epochs: 15
# tuner/initial_epoch: 5
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: c5cc64d6139c382d34ae87b788bc325e
# Score: 0.8849206268787384
# Trial summary
# Hyperparameters:
# Cov_filters_1: 16
# Cov_filters_2: 16
# dropout_1: 0.1
# Cov_filters_3: 16
# Cov_filters_4: 64
# dropout_2: 0.4
# units_1: 192
# dropout_4: 0.1
# learning_rate: 0.0008433633337952192
# tuner/epochs: 5
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: fa9d119582692e26e0a6c84d26e87a7f
# Score: 0.8531745970249176
# Trial summary
# Hyperparameters:
# Cov_filters_1: 16
# Cov_filters_2: 16
# dropout_1: 0.1
# Cov_filters_3: 16
# Cov_filters_4: 64
# dropout_2: 0.4
# units_1: 192
# dropout_4: 0.1
# learning_rate: 0.0008433633337952192
# tuner/epochs: 15
# tuner/initial_epoch: 5
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 4eb5c9da05d6590f4f9c6c26b260d7ab
# Score: 0.8134920597076416
# Trial summary
# Hyperparameters:
# Cov_filters_1: 16
# Cov_filters_2: 64
# dropout_1: 0.0
# Cov_filters_3: 64
# Cov_filters_4: 16
# dropout_2: 0.15000000000000002
# units_1: 256
# dropout_4: 0.45
# learning_rate: 0.0007767449713530701
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.7301587164402008
# Trial summary
# Hyperparameters:
# Cov_filters_1: 32
# Cov_filters_2: 32
# dropout_1: 0.4
# Cov_filters_3: 32
# Cov_filters_4: 16
# dropout_2: 0.1
# units_1: 448
# dropout_4: 0.4
# learning_rate: 0.0003021384939866327
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.710317462682724
