# %%
# Imports
import librosa, librosa.display
import matplotlib.pyplot as plt
import os
import numpy as np
import math
import json
import cv2

# %%
# Paths
DATASET_AUDIO_TRAIN = "Data/Train/Pre/Audio"
JSON_AUDIO = "JSON/Train_audio.json"

DATASET_AUDIO_TEST = "Data/Test/Pre/Audio"
JSON_AUDIO_TEST = "JSON/Test_audio.json"

# Audio Var
SAMPLE_RATE = 22050
DURATION = 4
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION

# %%
# Process audio and image data - store in data.json file
def save_data(audio_path, json_path, n_mfcc=13, n_fft=2048, hop_length=512, num_segments=1):
    data = {
        "mapping": [],
        "mfcc": [],
        "labels": []
    }
    
    # how many samples for each audio input
    num_samples_per_segment = int(SAMPLES_PER_TRACK / num_segments) 
    # number of mfccs if samples are made
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment / hop_length) 
    
    # walk through audio directories
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(audio_path)):
        if dirpath is not audio_path:
            dirpath_components = dirpath.split("/")
            semantic_label = dirpath_components[-1]
            # store the directories opened
            data["mapping"].append(semantic_label)
            
            print("\nProcessing {}".format(semantic_label))
            
            for f in filenames:
                try:
                    file_path = os.path.join(dirpath, f)
                    signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
                except Exception as e:                                                    
                    print('Audio failed to process: ' + e)
                
                for s in range(num_segments):
                    # Process audio
                    start_sample = num_samples_per_segment * s
                    finish_sample = start_sample + num_samples_per_segment
                        
                    mfcc = librosa.feature.mfcc(signal[start_sample:finish_sample],
                                               sr=sr,
                                               n_fft=n_fft,
                                               n_mfcc=n_mfcc,
                                               hop_length=hop_length)

                    mfcc = mfcc.T
                    
                    if len(mfcc) == expected_num_mfcc_vectors_per_segment:
                        # store mfcc data
                        data["mfcc"].append(mfcc.tolist())
                        # store audio type
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, s+1))
    
    
    # dump stored data into json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        

save_data(DATASET_AUDIO_TRAIN, JSON_AUDIO, num_segments=1)
save_data(DATASET_AUDIO_TEST, JSON_AUDIO_TEST, num_segments=1)
# Out:
# Processing Audio\Happy
# Data/Train/Pre/Audio\Happy\0.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_0.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_1.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_10.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_11.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_12.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_13.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_14.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_15.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_16.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_17.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_18.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_19.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_2.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_20.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_21.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_22.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_23.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_24.wav, segment:1
# Data/Train/Pre/Audio\Happy\0_25.wav, segment:1
# ...
